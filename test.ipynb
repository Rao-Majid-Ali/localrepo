# %%
print("hello world")
# Out:
# hello world

# %%
txt = input("input some thing  : ")
print(txt)
# Out:
# input some thing  :  i am learning python
# i am learning python

# %%
g = 1.03
type(g)
# Out:
# float

# %%
z = 1+2j
type(z)
# Out:
# complex
